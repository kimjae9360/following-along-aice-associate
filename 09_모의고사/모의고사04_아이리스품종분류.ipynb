# %% [markdown]
# # 모의고사 04. 아이리스 품종 분류 (다중분류)
#
# > 실제 시험처럼 이론 설명 없이 문제만 순서대로 제시합니다. **90분 타이머를 맞추고** 풀어보세요. 오픈북 허용 문서(numpy/pandas/matplotlib/seaborn/scikit-learn/tensorflow/XGBoost 공식문서)만 참고할 수 있다고 가정합니다.
#
# ### 데이터 소개
# `data/iris.csv` - 꽃잎/꽃받침 크기로 붓꽃 품종(target 0/1/2, 각 50개씩 균형)을 분류합니다. 이번 회차는 KNN, SVC 등 03번과 다른 모델로 연습합니다.
#
# > ⏱️ **[실전 타임어택 가이드]** 데이터 탐색 10분 ➔ 전처리 20분 ➔ 머신러닝 30분 ➔ 딥러닝 30분
# > 막히는 부분은 주석으로 남기고 다음 문제로 넘어가는 것이 합격 전략입니다.

# %% [markdown]
# ## 목차
# 1교시 데이터 로딩 & EDA · 2교시 데이터 시각화 · 3교시 데이터 전처리 · 4교시 머신러닝 모델링 · 5교시 딥러닝 모델링 · 채점 가이드

# %%
import sys
sys.path.insert(0, '../00_시작하기')
import aice_grader as grader

# 실전처럼 시간 제한(90분)을 두고 풀어보세요. 아래 셀을 실행하면 타이머가 시작됩니다.
timer = grader.ExamTimer(minutes=90)
timer.start()

# %% [markdown]
# ## 1교시: 데이터 로딩 & EDA

# %% [markdown]
# **문제 1.** `pandas`, `numpy`, `matplotlib.pyplot`, `seaborn`을 각각 `pd`, `np`, `plt`, `sns`로 불러오고, `../data/iris.csv`을 `iris`로 불러와 shape을 확인하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# iris = pd.read_csv('../data/iris.csv')
# iris.head()
# print(iris.shape)
# ```
#
# </details>

# %% [markdown]
# **문제 2.** `iris`의 `target` 분포가 균형인지 확인하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# print(iris['target'].value_counts())  # 각 클래스 개수가 비슷하면 균형 데이터라는 뜻  # 범주형 데이터의 항목별 개수를 세어 데이터 분포 확인
# ```
#
# </details>

# %% [markdown]
# **문제 3.** `petal length (cm)`과 `petal width (cm)`의 상관계수를 구하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# print(iris['petal length (cm)'].corr(iris['petal width (cm)']))  # 1에 가까울수록 두 변수가 함께 커지는 강한 양의 상관관계  # 수치형 변수 간의 상관계수를 계산하여 서로의 연관성 파악
# ```
#
# </details>

# %% [markdown]
# ## 2교시: 데이터 시각화

# %% [markdown]
# **문제 4.** `sepal length (cm)`, `sepal width (cm)`를 `target`으로 색을 나눠 scatterplot을 그리세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# sns.scatterplot(data=iris, x='sepal length (cm)', y='sepal width (cm)', hue='target', palette='Set1')  # 두 변수 간의 관계를 산점도로 시각화
# plt.show()
# ```
#
# </details>

# %% [markdown]
# **문제 5.** `target`별 `petal length (cm)` 분포를 violinplot으로 비교하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# sns.violinplot(x='target', y='petal length (cm)', data=iris)  # 값의 분포와 밀도를 바이올린 형태로 시각화
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ## 3교시: 데이터 전처리

# %% [markdown]
# **문제 6.** `train_test_split(test_size=0.2, stratify=y, random_state=42)`로 분할하고 `StandardScaler`로 스케일링하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# X = iris.drop(columns=['target'])
# y = iris['target']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)  # 데이터를 모델 학습용(train)과 검증용(test)으로 분리
# scaler = StandardScaler()  # 데이터를 평균 0, 표준편차 1이 되도록 스케일링 (거리 기반, 딥러닝 알고리즘에 필수)
# X_train_s = scaler.fit_transform(X_train)  # 훈련 데이터로 스케일링 기준을 학습(fit)하고 변환(transform)까지 수행
# X_test_s = scaler.transform(X_test)  # 훈련 데이터에서 학습된 기준을 그대로 적용하여 평가 데이터를 변환 (데이터 누수 방지)
# ```
#
# </details>

# %% [markdown]
# ## 4교시: 머신러닝 모델링

# %% [markdown]
# **문제 7.** `KNeighborsClassifier(n_neighbors=5)`를 학습시키고 accuracy를 구하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.metrics import accuracy_score
# knn = KNeighborsClassifier(n_neighbors=5)  # K-최근접 이웃 알고리즘(KNN) 모델 생성
# knn.fit(X_train_s, y_train)
# print(accuracy_score(y_test, knn.predict(X_test_s)))  # 전체 예측 중 올바르게 맞춘 비율(정확도) 계산
# ```
#
# </details>

# %% [markdown]
# **문제 8.** `SVC(kernel='rbf', random_state=42)`를 학습시키고 classification_report를 출력하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# from sklearn.svm import SVC
# from sklearn.metrics import classification_report
# svc = SVC(kernel='rbf', random_state=42)  # 서포트 벡터 머신(SVM) 분류 모델 생성
# svc.fit(X_train_s, y_train)
# print(classification_report(y_test, svc.predict(X_test_s)))
# ```
#
# </details>

# %% [markdown]
# ## 5교시: 딥러닝 모델링

# %% [markdown]
# **문제 9.** 출력층 노드=3(softmax)인 모델을 만들어 학습시키고 argmax로 accuracy를 구하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.callbacks import EarlyStopping
# from sklearn.metrics import accuracy_score
# model = Sequential()  # 딥러닝 층(Layer)을 순서대로 쌓기 위한 기본 틀(모델) 생성
# model.add(Dense(16, activation='relu', input_shape=(X_train_s.shape[1],)))  # 이전 층의 모든 노드와 연결되는 완전 연결층(Dense Layer) 추가
# model.add(Dense(3, activation='softmax'))  # 이전 층의 모든 노드와 연결되는 완전 연결층(Dense Layer) 추가
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])  # 모델 학습 과정(최적화 기법, 손실 함수, 평가지표) 설정
# es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)  # 성능이 개선되지 않으면 무의미한 학습을 일찍 멈춤
# model.fit(X_train_s, y_train, epochs=100, batch_size=8, validation_data=(X_test_s, y_test), callbacks=[es], verbose=0)
# pred = np.argmax(model.predict(X_test_s), axis=1)  # 다중 분류 결과에서 각 샘플 중 가장 확률이 높은 클래스 인덱스를 추출
# print(accuracy_score(y_test, pred))  # 전체 예측 중 올바르게 맞춘 비율(정확도) 계산
# ```
#
# </details>

# %%
# 문제를 다 풀었다면 아래 셀을 실행해 소요 시간을 확인하세요.
timer.finish()

# %% [markdown]
# ## 채점 가이드 (100점 만점 배점표)
#
# 이 모의고사는 총 9문제, 100점 만점입니다. 각 문제를 정답과 비교해 맞았으면 배점만큼, 틀렸으면 0점으로 스스로 채점해보세요.
#
# | 문항 | 배점 |
# |---|---|
# | 문제 1 | 11점 |
# | 문제 2 | 11점 |
# | 문제 3 | 11점 |
# | 문제 4 | 11점 |
# | 문제 5 | 11점 |
# | 문제 6 | 11점 |
# | 문제 7 | 11점 |
# | 문제 8 | 11점 |
# | 문제 9 | 12점 |
# | **합계** | **100점** |
#
# > 💡 **합격 기준: 80점 이상** (실제 AICE Associate와 동일한 기준입니다)
#
# ### 자동으로 기록하며 채점하고 싶다면
#
# `00_시작하기/aice_grader.py`의 `MockExamGrader`를 사용하면 점수를 자동으로 합산해줍니다.
#
# ```python
# import aice_grader as grader
#
# g = grader.MockExamGrader("모의고사04_아이리스품종분류")
# g.check(1, points=11, is_correct=True)   # 문제 1을 맞았으면 True, 틀렸으면 False
# g.check(2, points=11, is_correct=True)
# # ... 문제 수만큼 반복 ...
# g.report()   # 최종 점수와 합격 여부를 출력
# ```
#
# ### 개념 체크리스트
#
# 다 풀었다면 아래 체크리스트로 한 번 더 점검해보세요.
#
# - [ ] 라이브러리를 정확한 alias(pd, np, plt, sns 등)로 불러왔는가
# - [ ] stratify로 클래스 비율을 유지해 분할했는가
# - [ ] KNN/SVC 모두 스케일링된 데이터를 입력했는가
# - [ ] 다중분류 DL 출력층 설계가 올바른가
