# %% [markdown]
# # 01. 데이터 로딩 & 기본 탐색 - 실무전용 문제 모음
#
# > **실무 전용 노트북** - 이론 설명 없이 TODO 문제만 모았습니다. (관련 이론 노트북: 02_EDA_데이터로딩_탐색.ipynb)
# 이미 개념은 이해했다는 전제로, 손으로 더 많이 풀어보며 완전히 몸에 익히는 것이 목표입니다. 정답을 먼저 보지 말고 반드시 스스로 코드를 작성해본 뒤 펼쳐서 비교하세요.
#
# 이론 노트북에서는 train.csv 위주였다면, 여기서는 **data.json·sample.xlsx·test.csv·wine.csv**를 골고루 다시 불러오고 탐색합니다.

# %% [markdown]
# ## 목차
# 1. 다양한 포맷 로딩 연습
# 2. 병합 연습
# 3. 데이터 기본 탐색 연습

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. 다양한 포맷 로딩 연습

# %% [markdown]
# **문제 1.** `../data/data.json`을 읽어 `shop_df`에 저장하고 shape을 확인하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# shop_df = pd.read_json('../data/data.json')  # JSON 파일은 read_json으로 바로 DataFrame으로 변환됨
# print(shop_df.shape)
# shop_df
# ```
#
# </details>

# %% [markdown]
# **문제 2.** `../data/sample.xlsx`를 읽어 `sales_df`에 저장하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# sales_df = pd.read_excel('../data/sample.xlsx')  # xlsx 확장자는 read_excel 사용
# sales_df
# ```
#
# </details>

# %% [markdown]
# **문제 3.** `../data/wine.csv`를 읽되 `alcohol`, `target` 두 컬럼만 골라 `wine_partial`에 저장하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# wine_partial = pd.read_csv('../data/wine.csv', usecols=['alcohol', 'target'])  # usecols로 필요한 컬럼만 선택해 불필요한 로딩을 줄임
# wine_partial.head()
# ```
#
# </details>

# %% [markdown]
# ## 2. 병합 연습

# %% [markdown]
# **문제 4.** `../data/train.csv`와 `../data/test.csv`를 `PassengerId` 기준 `outer`로 병합해 shape을 확인하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# train = pd.read_csv('../data/train.csv')
# test = pd.read_csv('../data/test.csv')
# merged = pd.merge(train, test, on='PassengerId', how='outer')  # how='outer': 한쪽에만 있는 행도 버리지 않고 포함(없는 값은 NaN)
# print(merged.shape)
# ```
#
# </details>

# %% [markdown]
# ## 3. 데이터 기본 탐색 연습

# %% [markdown]
# **문제 5.** `shop_df`의 컬럼별 데이터 타입을 확인하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# shop_df.dtypes  # 컬럼별 타입만 간단히 보고 싶을 때는 info() 대신 dtypes를 바로 사용해도 됨
# ```
#
# </details>

# %% [markdown]
# **문제 6.** `wine_partial`에서 `target`별 개수를 `value_counts()`로 확인하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# wine_partial['target'].value_counts()  # target 클래스별 데이터 개수를 확인해 불균형 여부를 미리 체크
# ```
#
# </details>

# %% [markdown]
# **문제 7.** `sales_df`에서 수치형 컬럼만 `select_dtypes`로 골라 `sales_numeric`에 저장하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# sales_numeric = sales_df.select_dtypes(include='number')  # include='number'는 int/float 계열 컬럼만 골라줌
# sales_numeric
# ```
#
# </details>

# %% [markdown]
# **문제 8.** `train`에서 `Pclass`와 `Survived`의 교차표를 `pd.crosstab`으로 만드세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# <details>
# <summary>✅ 정답 보기</summary>
#
# ```python
# pd.crosstab(train['Pclass'], train['Survived'])  # 좌석 등급별 생존/사망 인원을 교차표로 한눈에 비교
# ```
#
# </details>
